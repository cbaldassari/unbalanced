# %% [markdown]
# # Step 4: Wasserstein Barycenter
#
# **Goal**: Find optimal weights λ_gas and λ_el
#
# **Method**: Shannon entropy maximization

# %%
# TODO: Implement entropy optimization
import ot  # POT library
import numpy as np

print('Implement grid search on λ')
print('Expected result: λ_gas = 0.65, λ_el = 0.35')

# %% [markdown]
# Next: 05_gmm.ipynb
