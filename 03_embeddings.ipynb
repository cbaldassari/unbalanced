# %% [markdown]
# # Step 3: Graph Embeddings (Diff2Vec)
#
# **Goal**: Transform graphs into 128-dimensional vectors

# %%
# TODO: Implement Diff2Vec embeddings
from karateclub import Diff2Vec
import numpy as np
import pickle

print('Load graphs and apply Diff2Vec (128 dimensions)')
print('Expected output: embeddings shape (1825, 128)')

# %% [markdown]
# Next: 04_wasserstein.ipynb
